# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import time

def get_title(soup):
    try:
        title = soup.find("a",attrs={'class' : 'wjcEIp'})
        title_value = title.text
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

def get_mrp(soup):

    try:
        mrp_info = soup.find('div', {'class': 'yRaY8j'})
        mrp = mrp_info.text.strip()

    except AttributeError:
        mrp = ""
        
    return mrp


def get_price(soup):
    
    try:
        price_element = soup.find("div", attrs={'class':'Nx9bqj'})
        price = price_element.text.strip()
        
    except AttributeError:
        price = ""

    return price

def get_discount(soup):

    try:
        discount_info = soup.find('div', {'class': 'UkUFwK'})
        discount = discount_info.text.strip()
        
    except AttributeError:
        discount = ""
        
    return discount

def get_rating(soup):

    try:
        rating = soup.find("div", attrs={'class':'XQDdHH'}).text.strip()

    except AttributeError:
        rating = ""
    
    return rating

def get_reviews(soup):
    try:
        reviews = soup.find("span", attrs={'class':'Wphh3N'}).text.strip()

    except AttributeError:
        reviews = ""

    return reviews

if __name__ == '__main__':
    URL = "https://www.flipkart.com/search?q=headphones&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

    response = requests.get(URL)
    soup = BeautifulSoup(response.content, "html.parser")
    
    links = soup.find_all("a", attrs={"class": "VJA3rP"})
    links_list = []
    for link in links:
        links_list.append(link.get('href'))
        
    d = {"title": [], "mrp":[], "price": [], "discount": [], "rating": [], "reviews": []}

    for link in links_list:
        new_webpage = requests.get("https://www.flipkart.com" + link)
        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        d["title"].append(get_title(new_soup))
        d["mrp"].append(get_mrp(new_soup))        
        d["price"].append(get_price(new_soup))
        d["discount"].append(get_discount(new_soup))
        d["rating"].append(get_rating(new_soup))
        d["reviews"].append(get_reviews(new_soup))        

df = pd.DataFrame.from_dict(d)
df['title'].replace('', np.nan, inplace = True)
df = df.dropna(subset = ['title'])
df.to_csv("flip_data4.csv", header = True, index = False)
# Out:
# C:\Users\OMKAR\AppData\Local\Temp\ipykernel_30148\1055529657.py:96: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['title'].replace('', np.nan, inplace = True)

# %%
df = pd.read_csv("flip_data4.csv")
print(df)
# Out:
#                                                 title      mrp    price  \
# 0   Aroma NB119 Care 48 Hours Playing Time Fast Ch...   ₹1,999     ₹300
# 1   Apple AirPods Pro (2nd generation) with MagSaf...  ₹24,900  ₹17,999
# 2   Apple AirPods(2nd gen) with Charging Case Blue...  ₹12,900   ₹7,499
# 3               OnePlus Bullets Wireless Z2 Bluetooth   ₹2,299   ₹1,399
# 4   Noise Buds VS102 with 50 Hrs Playtime, 11mm Dr...   ₹2,999     ₹799
# 5   Boult W20 with Zen ENC Mic, 35H Battery Life, ...   ₹2,499     ₹849
# 6   Brolan Blue Wireless Ear Buds witth multiple f...   ₹2,299     ₹629
# 7   boAt Airdopes 161/163 with ASAP Charge & 40 HR...   ₹2,490     ₹899
# 8   Aroma NB140 Superstar Upto 55 Hours* Playtime ...   ₹2,499     ₹480
# 9   Aroma NB120 Amaze Upto 50 Hours* Playtime, Fas...   ₹2,999     ₹399
# 10  ROAR WU-1045 P47 Headset Super Extra Bass Blue...     ₹899     ₹449
# 11  Noise Buds VS102 with 50 Hrs Playtime, 11mm Dr...   ₹2,999     ₹799
# 12  TRIGGR Trinity 1 with 40mm Drivers, Fast Charg...   ₹2,999     ₹799
# 13                         SORAK CREATION 8 Bluetooth     ₹999     ₹429
# 14  Aroma NB128 Happy 24 Hours Playting Time Deep ...   ₹1,499     ₹267
# 15  Boult Y1 with Zen ENC Mic, 50H Battery, Fast C...   ₹5,499     ₹899
# 16              OnePlus Bullets Wireless Z2 Bluetooth   ₹2,299   ₹1,399
# 17  Boult Flex 80Hrs Battery, ENC Mic, 40mm Booste...   ₹5,499   ₹1,899
# 18  GUGGU M19 CrystalClear (Earbuds) HDAudio (Blue...     ₹999     ₹489
# 19  realme Buds Wireless 3 Neo with 13.4mm Driver,...   ₹2,499   ₹1,299
# 20  Aroma NB119 Titanium - 48 Hours Playtime Neckb...   ₹2,499     ₹450
# 21                  HOUSE OF SOUND T-12 MAX Bluetooth   ₹1,999     ₹379
# 22  TECHNUV S460 ANC High Quality Pure Sound, IPX5...   ₹2,499     ₹599
# 23                                     boAt 100 Wired     ₹999     ₹349
# 24  Boult W40 with Quad Mic ENC, 48H Battery Life,...   ₹2,999     ₹899
# 25  Aroma NB120 Amaze Upto 50 Hours* Playtime, Fas...   ₹2,999     ₹399
#
#    discount  rating                               reviews
# 0   84% off     3.9        48,861 Ratings & 3,469 Reviews
# 1   27% off     4.6          18,561 Ratings & 970 Reviews
# 2   41% off     4.5      1,51,262 Ratings & 8,165 Reviews
# 3   39% off     4.3    10,98,250 Ratings & 63,633 Reviews
# 4   73% off     4.0     5,70,200 Ratings & 42,176 Reviews
# 5   66% off     4.1      1,39,969 Ratings & 8,350 Reviews
# 6   72% off     3.5                47 Ratings & 0 Reviews
# 7   63% off     4.0    11,87,744 Ratings & 76,116 Reviews
# 8   80% off     3.8          11,843 Ratings & 618 Reviews
# 9   86% off     3.9        18,012 Ratings & 1,130 Reviews
# 10  50% off     3.5                 4 Ratings & 1 Reviews
# 11  73% off     4.0     5,70,200 Ratings & 42,176 Reviews
# 12  73% off     3.8           3,650 Ratings & 608 Reviews
# 13  57% off     3.6              291 Ratings & 10 Reviews
# 14  82% off     3.4           6,797 Ratings & 370 Reviews
# 15  83% off     4.0     4,37,874 Ratings & 34,535 Reviews
# 16  39% off     4.3    10,98,250 Ratings & 63,633 Reviews
# 17  65% off     4.1              379 Ratings & 78 Reviews
# 18  51% off     3.4               108 Ratings & 2 Reviews
# 19  48% off     4.2     4,30,259 Ratings & 30,557 Reviews
# 20  81% off     3.9     2,78,760 Ratings & 15,760 Reviews
# 21  81% off     3.4           9,169 Ratings & 266 Reviews
# 22  76% off     3.9              338 Ratings & 13 Reviews
# 23  65% off     4.3  14,20,402 Ratings & 1,17,585 Reviews
# 24  70% off     4.1      1,15,340 Ratings & 9,514 Reviews
# 25  86% off     3.9        18,012 Ratings & 1,130 Reviews
